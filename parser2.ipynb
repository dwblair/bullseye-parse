# %%
# %matplotlib inline  
import os
import json
import pylab
import numpy as np
import glob

# %%
sparklist=glob.glob('data2/*SPARK*.json')
print(sparklist)
#os.listdir('data2')
# Out:
# ['data2/Bullseye-20170322-121728746-One-sample-000015-SPARK.json', 'data2/Bullseye-20170322-122003611-One-sample-000020-SPARK.json', 'data2/Bullseye-20170322-121739527-One-sample-000016-SPARK.json', 'data2/Bullseye-20170322-121755947-One-sample-000017-SPARK.json', 'data2/Bullseye-20170322-121700837-One-sample-000013-SPARK.json', 'data2/Bullseye-20170322-121144676-One-sample-000008-SPARK.json', 'data2/Bullseye-20170322-121645098-One-sample-000012-SPARK.json', 'data2/Bullseye-20170322-121124874-One-sample-000007-SPARK.json', 'data2/Bullseye-20170322-121933622-One-sample-000018-SPARK.json', 'data2/Bullseye-20170322-122013952-One-sample-000021-SPARK.json', 'data2/Bullseye-20170322-121947010-One-sample-000019-SPARK.json', 'data2/Bullseye-20170322-121716134-One-sample-000014-SPARK.json']

# %%
def plotter(filename,spectrum):
    with open(filename) as data_file:
        data = json.load(data_file)
    x=data["spectrometer"]["wavelengths"]
    y=data["spectra"][spectrum]
    pylab.plot(x, y,label=filename.split('-')[6].split('.')[0])
    #pylab.title(spectrum)
    pylab.xlabel('nm')

# %%
type='SPARK'
sparklist=glob.glob('data2/*'+type+'*.json')
for filename in sparklist:
    plotter(filename,'absorbance')
pylab.title(type)

# %%
type='FLAME_NIR'
sparklist=glob.glob('data2/*'+type+'*.json')
for filename in sparklist:
    plotter(filename,'absorbance')
pylab.title(type)

# %%
type='QEPRO'
sparklist=glob.glob('data2/*'+type+'*.json')
for filename in sparklist:
    plotter(filename,'absorbance')
pylab.title(type)

# %%
type='QEPRO'
sparklist=glob.glob('data2/*'+type+'*.json')
for filename in sparklist:
    plotter(filename,'absorbance')
pylab.title(type)
